# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
df = pd.read_csv("C:\後藤研\修士研究\data\登記受付帳_築年数追加_前処理済み.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Barre\AppData\Local\Temp\ipykernel_19808\2985194278.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv("C:\後藤研\修士研究\data\登記受付帳_築年数追加_前処理済み.csv")
# C:\Users\Barre\AppData\Local\Temp\ipykernel_19808\2985194278.py:1: DtypeWarning: Columns (16,21,22,25,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\後藤研\修士研究\data\登記受付帳_築年数追加_前処理済み.csv")

# %%
df.head()
# Out:
#   register_num register_date register_type        reason  pref  city  \
# 0        39362    2023-10-06            単独   所有権移転その他の原因   栃木県  宇都宮市
# 1        39691    2023-10-11            単独  所有権移転相続・法人合併   栃木県  さくら市
# 2         8658    2023-10-11            連続            表題   愛媛県   今治市
# 3         8982    2023-10-20            単独            表題   愛媛県   今治市
# 4        32122    2023-10-04            連続            表題  和歌山県  和歌山市
#
#   new_or_existing  type        location    land_num  other  lat  lon  size  \
# 0               既    建物  宇都宮市インターパーク6丁目       5-3-2    NaN  NaN  NaN   NaN
# 1               既    建物          さくら市氏家     1359-35    NaN  NaN  NaN   NaN
# 2               新  区分建物      今治市北日吉町2丁目  1010-1-901    NaN  NaN  NaN   NaN
# 3               新    建物       今治市砂場町2丁目       232-3    NaN  NaN  NaN   NaN
# 4               新  区分建物       和歌山市太田1丁目    5-2-1201    NaN  NaN  NaN   NaN
#
#    building_coverage_ratio  floor_area_ratio use_district  official_price  \
# ...

# %%
df["reason"].unique()
# Out:
# array(['所有権移転その他の原因', '所有権移転相続・法人合併', '表題', ..., '表示に関するその他/8216/[表示]',
#        '附属建物の新築/【郵】【表示】送送', '減失/〔表示〕〔郵送/窓口〕'], dtype=object)

# %%
len(df["reason"].unique())
# Out:
# 4842

# %%
df["reason"].value_counts()
# Out:
# reason
# 所有権移転売買                       2924215
# 所有権移転相続・法人合併                  2608054
# 抵当権の設定                        2231780
# 抹消登記                          2226408
# 登記名義人の氏名等についての変更・更正           1553999
#                                ...
# 登記名義人の氏名等について!の変更更正/〔郵送/郵送          1
# 表示に関するその他/377/【表示】                  1
# 表示に関するその他/h×10                      1
# 減失/8330                             1
# 登記名義人の氏名等について、の変更更正/〔窓口/完了          1
# Name: count, Length: 4841, dtype: int64

# %%
# reason列の種類とその数を集計
reason_counts = df['reason'].value_counts()

# 数が10個以上の原因を抽出
reason_counts_10_or_more = reason_counts[reason_counts == 10]

# 結果を表示
print(reason_counts_10_or_more)
# Out:
# reason
# 表示に関するその他ｈ                10
# 減失/2044                   10
# 信託に関する登記/オン               10
# 減失/2012                   10
# 附属建物の新築/HOL               10
# 表示に関するその他／＠＋              10
# 表示に関するその他/札なし             10
# 減失/『H』                    10
# 信託に関する登記/〔窓口/郵送〕          10
# 土地改良区画整理/令和05年06月30日改良    10
# 土地改良区画整理/令和05年03月07日改良    10
# 表示に関するその他/HO              10
# 附属建物の新築/「表示」              10
# 表示に関するその他/オンー             10
# 附属建物の新築/オン表示調査士報告方式       10
# 土地改良区画整理/令和04年01月20日区画    10
# 減失/7211                   10
# 表示に関するその他1/-              10
# 減失/建物減失/オン表示              10
# 表示に関するその他／■■■■            10
# 附属建物の新築/表示・オン             10
# 地役権の設定//郵送希望              10
# Name: count, dtype: int64

# %%
# 主要な26個の登記原因リスト
valid_reasons = [
    "所有権移転売買", "所有権移転相続・法人合併", "抹消登記", "抵当権の設定", 
    "登記名義人の氏名等についての変更・更正", "所有権の保存(申請)", "表題", "滅失", 
    "地目変更・更正", "所有権移転遺贈・贈与その他無償名義", "分筆", "権利", 
    "変更・更正", "根抵当権の設定", "所有権移転その他の原因", "権利の移転(所有権を除く)", 
    "地積変更・更正", "区分建物の表題", "仮登記(その他)", "処分の制限に関する登記", 
    "合筆", "仮登記(所有権)", "所有権移転遺贈・贈与その他", "共同担保変更通知", 
    "抹消登記/嘱託", "処分の制限に関する登記/嘱託"
]

# 主要な原因に該当する行の数をカウント
valid_reason_counts = df[df['reason'].isin(valid_reasons)]['reason'].value_counts()

# 結果を表示
print(valid_reason_counts)
# Out:
# reason
# 所有権移転売買                2924215
# 所有権移転相続・法人合併           2608054
# 抵当権の設定                 2231780
# 抹消登記                   2226408
# 登記名義人の氏名等についての変更・更正    1553999
# 表題                     1167541
# 所有権の保存(申請)             1144592
# 権利                      561781
# 滅失                      504934
# 地目変更・更正                 460571
# 分筆                      419308
# 所有権移転遺贈・贈与その他無償名義       405100
# 変更・更正                   215622
# 所有権移転その他の原因             213186
# 仮登記(その他)                119511
# 処分の制限に関する登記             112004
# 合筆                       92743
# 仮登記(所有権)                 21765
# 地積変更・更正                  15361
# 共同担保変更通知                  1669
# 所有権移転遺贈・贈与その他              682
# 権利の移転(所有権を除く)              303
# 抹消登記/嘱託                    247
# 処分の制限に関する登記/嘱託              85
# Name: count, dtype: int64

# %% [markdown]
# 区分建物の表題，根抵当権の設定がない

# %%
df_26 = df[df['reason'].isin(valid_reasons)]

# %%
# 前処理されたデータを保存する場合
df_26.to_csv("./data/登記受付帳22-23_築年数追加_登記原因26個.csv", index=False)
