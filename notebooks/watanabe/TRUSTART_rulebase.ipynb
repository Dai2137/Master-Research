# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- ---------------
# absl-py                            1.4.0
# accelerate                         0.16.0
# adapt                              0.4.2
# aiohttp                            3.8.4
# aiosignal                          1.3.1
# alabaster                          0.7.12
# alembic                            1.8.1
# anaconda-anon-usage                0.4.2
# anaconda-client                    1.11.2
# anaconda-cloud-auth                0.5.0
# anaconda-navigator                 2.6.3
# anyio                              3.6.2
# appdirs                            1.4.4
# argon2-cffi                        21.3.0
# argon2-cffi-bindings               21.2.0
# arrow                              1.2.3
# astroid                            2.14.2
# astropy                            5.1
# asttokens                          2.1.0
# astunparse                         1.6.3
# ...

# %%
df_1v2_reason95_orderlog0_livedum_all = pd.read_csv('df_1v2_reason95_orderlog0_livedum_all.csv')
# Out:
# C:\Users\GUESTUSER\AppData\Local\Temp\ipykernel_5360\1688623676.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1v2_reason95_orderlog0_livedum_all = pd.read_csv('df_1v2_reason95_orderlog0_livedum_all.csv')

# %% [markdown]
# ## ルールベース（営業の指針）
# ・相続された物件は売られやすい
# ・処分の制限がされた物件は売られやすい
# ・都市部は売られやすい

# %%
len(df_1v2_reason95_orderlog0_livedum_all[df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1])
# Out:
# 1429817

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 450)])
# Out:
# 81061

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 30)])
# Out:
# 15339

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 60)])
# Out:
# 31501

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 90)])
# Out:
# 42782

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 180)])
# Out:
# 65007

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 360)])
# Out:
# 79749

# %%
len(df_1v2_reason95_orderlog0_livedum_all[df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1])
# Out:
# 55600

# %%
len(df_1v2_reason95_orderlog0_livedum_all[df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記/嘱託"] == 1])
# Out:
# 115

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 450)])
# Out:
# 4302

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 30)])
# Out:
# 315

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 60)])
# Out:
# 791

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 90)])
# Out:
# 1349

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 180)])
# Out:
# 2809

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 360)])
# Out:
# 4156

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
    (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記/嘱託"] == 1) &
    (df_1v2_reason95_orderlog0_livedum_all["sales1_period"] <= 450)])
# Out:
# 7

# %% [markdown]
# ### 都市部
# 大都市(総務省)：大阪，名古屋，京都，横浜，神戸，北九州，札幌，川崎，福岡，広島，仙台，千葉，さいたま，静岡，堺，新潟，浜松，岡山，相模原，熊本，東京23区
# 都道府県：大阪，愛知，京都，神奈川，兵庫，福岡，北海道，福岡，広島，宮城，千葉，埼玉，静岡，新潟，岡山，熊本，東京
# https://www.soumu.go.jp/main_sosiki/jichi_gyousei/bunken/shitei_toshi-ichiran.html

# %%
prefecture_density = {
    '北海道': 66.6,  '宮城県': 316.1, '埼玉県': 1934.0, '千葉県': 1218.5, '東京都': 6402.6, '神奈川県': 3823.2, '静岡県': 467.2,
    '愛知県': 1458.0, '三重県': 306.6, '京都府': 559.0, '大阪府': 4638.4, '兵庫県': 650.5, '岡山県': 265.4, '広島県': 330.2, 
    '福岡県': 1029.8, '熊本県': 234.6, '新潟県': 174.9
}

# %%
df_1v2_reason95_orderlog0_livedum_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5765606 entries, 0 to 5765605
# Data columns (total 58 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   register_num               object
#  1   register_date              object
#  2   register_type              object
#  3   pref                       object
#  4   location                   object
#  5   land_num                   object
#  6   other                      float64
#  7   city                       object
#  8   size                       float64
#  9   use_district               object
#  10  lat                        float64
#  11  lon                        float64
#  12  building_coverage_ratio    float64
#  13  floor_area_ratio           float64
#  14  official_price             float64
#  15  land_price                 float64
#  16  location_all               object
#  17  year_month                 object
#  18  land_id                    float64
# ...

# %%
len(df_1v2_reason95_orderlog0_livedum_all[df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)])
# Out:
# 3730904

# %%
# prefecture_density の値をセットとして定義
population_density_values = {66.6, 316.1, 1934.0, 1218.5, 6402.6, 3823.2, 467.2, 
                             1458.0, 306.6, 559.0, 4638.4, 650.5, 265.4, 330.2, 
                             1029.8, 234.6, 174.9}

# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 30)])
# Out:
# 144795

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 60)])
# Out:
# 196039

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 90)])
# Out:
# 224388

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 180)])
# Out:
# 275816

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 360)])
# Out:
# 310819

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 450)])
# Out:
# 314101

# %% [markdown]
# ### 都市部＆相続

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1)])
# Out:
# 869204

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 30)])
# Out:
# 9875

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 60)])
# Out:
# 21626

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 90)])
# Out:
# 29951

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 180)])
# Out:
# 47315

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 360)])
# Out:
# 58919

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_所有権移転相続・法人合併"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 450)])
# Out:
# 59992

# %% [markdown]
# ### 都市部＆処分

# %%
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1)])
# Out:
# 42517

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 30)])
# Out:
# 275

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 60)])
# Out:
# 679

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 90)])
# Out:
# 1149

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 180)])
# Out:
# 2418

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 360)])
# Out:
# 3555

# %%
# 条件を満たす行を抽出して行数をカウント
len(df_1v2_reason95_orderlog0_livedum_all[
        (df_1v2_reason95_orderlog0_livedum_all['population_density'].isin(population_density_values)) &
        (df_1v2_reason95_orderlog0_livedum_all["dummy_処分の制限に関する登記"] == 1) &
        (df_1v2_reason95_orderlog0_livedum_all['sales1_period'] <= 450)])
# Out:
# 3683
