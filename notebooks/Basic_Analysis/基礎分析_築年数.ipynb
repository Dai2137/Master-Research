# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
df = pd.read_csv("C:/Users/GUESTUSER/Desktop/fujiwara/data/登記受付帳_築年数追加.csv")
# Out:
# C:\Users\GUESTUSER\AppData\Local\Temp\ipykernel_5144\2860721598.py:1: DtypeWarning: Columns (16,21,22,25,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/GUESTUSER/Desktop/fujiwara/data/登記受付帳_築年数追加.csv")

# %%
df.head()
# Out:
#   register_num register_date register_type        reason  pref  city  \
# 0        39362    2023-10-06            単独   所有権移転その他の原因   栃木県  宇都宮市
# 1        39691    2023-10-11            単独  所有権移転相続・法人合併   栃木県  さくら市
# 2         8658    2023-10-11            連続       区分建物の表題   愛媛県   今治市
# 3         8982    2023-10-20            単独            表題   愛媛県   今治市
# 4        32122    2023-10-04            連続  区分建物の表題/「表示」  和歌山県  和歌山市
#
#   new_or_existing  type        location    land_num  other  lat  lon  size  \
# 0               既    建物  宇都宮市インターパーク6丁目       5-3-2    NaN  NaN  NaN   NaN
# 1               既    建物          さくら市氏家     1359-35    NaN  NaN  NaN   NaN
# 2               新  区分建物      今治市北日吉町2丁目  1010-1-901    NaN  NaN  NaN   NaN
# 3               新    建物       今治市砂場町2丁目       232-3    NaN  NaN  NaN   NaN
# 4               新  区分建物       和歌山市太田1丁目    5-2-1201    NaN  NaN  NaN   NaN
#
#    building_coverage_ratio  floor_area_ratio use_district  official_price  \
# ...

# %%
df['type'].unique()
# Out:
# array(['建物', '区分建物', '一棟', '土地', '共担', 'その他'], dtype=object)

# %%
df[(df['register_num']=='3768') & (df['pref']=='東京都')]
# Out:
#          register_num register_date register_type               reason pref  \
# 146406           3768    2023-01-31            連先                 抹消登記  東京都
# 207205           3768    2023-03-09            連続                 抹消登記  東京都
# 284706           3768    2023-02-09            単独         所有権移転相続・法人合併  東京都
# 298752           3768    2023-01-31            連先  登記名義人の氏名等についての変更・更正  東京都
# 1740570          3768    2023-02-16            単独         所有権移転相続・法人合併  東京都
# 1794062          3768    2023-02-09            連続                 抹消登記  東京都
# 2447823          3768    2023-02-17            連続               抵当権の設定  東京都
# 2603760          3768    2023-01-31            連続         所有権移転相続・法人合併  東京都
# 2681143          3768    2023-02-28            連先                 抹消登記  東京都
# 3363243          3768    2023-02-07            単独              所有権移転売買  東京都
# 3582546          3768    2023-02-03            連続              所有権移転売買  東京都
# ...

# %%
df_with_building_age = df[df['building_age'].notnull()]

# %%
fraction = 1 / 200
# 指定された割合でランダムにサンプリング
sampled_df = df_with_building_age.sample(frac=fraction)

# サンプルデータを新しいCSVファイルとして保存
sampled_df.to_csv('登記受付帳_築年数追加_200分の1.csv')

# %%
df_with_building_age.head()
# Out:
#      register_num register_date register_type   reason pref    city  \
# 1086          174    2023-01-05            単独     抹消登記  宮城県   仙台市泉区
# 1841         1005    2023-01-20            連先  所有権移転売買  東京都     新宿区
# 1842         1032    2023-01-20            連続  所有権移転売買  東京都     新宿区
# 1843         1033    2023-01-20            連続   抵当権の設定  東京都     新宿区
# 6369        53909    2023-10-26            連先  所有権移転売買  大阪府  大阪市平野区
#
#      new_or_existing  type       location    land_num  other  lat  lon  size  \
# 1086               既  区分建物  仙台市泉区八乙女中央5丁目     246-111    NaN  NaN  NaN   NaN
# 1841               既  区分建物      新宿区北新宿3丁目  942-4-1002    NaN  NaN  NaN   NaN
# 1842               既  区分建物      新宿区北新宿3丁目  942-4-1002    NaN  NaN  NaN   NaN
# 1843               既  区分建物      新宿区北新宿3丁目  942-4-1002    NaN  NaN  NaN   NaN
# 6369               既  区分建物   大阪市平野区加美西2丁目    3-7-1001    NaN  NaN  NaN   NaN
#
#       building_coverage_ratio  floor_area_ratio use_district  official_price  \
# ...

# %%
len(df_with_building_age)
# Out:
# 1028184

# %%
df_with_building_age[df_with_building_age["reason"]=="所有権移転売買"]
# Out:
#          register_num register_date register_type   reason pref    city  \
# 1841             1005    2023-01-20            連先  所有権移転売買  東京都     新宿区
# 1842             1032    2023-01-20            連続  所有権移転売買  東京都     新宿区
# 6369            53909    2023-10-26            連先  所有権移転売買  大阪府  大阪市平野区
# 19339           30505    2023-12-25            単独  所有権移転売買  岩手県     盛岡市
# 24975           23471    2023-11-16            連続  所有権移転売買  千葉県     印西市
# ...               ...           ...           ...      ...  ...     ...
# 17196198          490    2022-02-01            連続  所有権移転売買  京都府     舞鶴市
# 17196202        24008    2022-06-27            連続  所有権移転売買  東京都     中央区
# 17196207        31288    2022-11-30            連続  所有権移転売買  東京都     新宿区
# 17196209        45909    2022-12-23            単独  所有権移転売買  埼玉県     狭山市
# 17196214         5160    2022-02-25            連続  所有権移転売買  東京都     杉並区
#
#          new_or_existing  type      location    land_num  other  lat  lon  \
# ...

# %%
df_with_building_age["reason"].unique()
# Out:
# array(['抹消登記', '所有権移転売買', '抵当権の設定', ..., '登記名義人の氏名等についての変更更正/1829',
#        '抹消登記/9656', '抹消登記/2753'], dtype=object)

# %%
df_ownership_transfer = df_with_building_age[df_with_building_age['reason'].str.contains('所有権移転売買', na=False)]

# %%
df_ownership_transfer
# Out:
#          register_num register_date register_type   reason pref    city  \
# 1841             1005    2023-01-20            連先  所有権移転売買  東京都     新宿区
# 1842             1032    2023-01-20            連続  所有権移転売買  東京都     新宿区
# 6369            53909    2023-10-26            連先  所有権移転売買  大阪府  大阪市平野区
# 19339           30505    2023-12-25            単独  所有権移転売買  岩手県     盛岡市
# 24975           23471    2023-11-16            連続  所有権移転売買  千葉県     印西市
# ...               ...           ...           ...      ...  ...     ...
# 17196198          490    2022-02-01            連続  所有権移転売買  京都府     舞鶴市
# 17196202        24008    2022-06-27            連続  所有権移転売買  東京都     中央区
# 17196207        31288    2022-11-30            連続  所有権移転売買  東京都     新宿区
# 17196209        45909    2022-12-23            単独  所有権移転売買  埼玉県     狭山市
# 17196214         5160    2022-02-25            連続  所有権移転売買  東京都     杉並区
#
#          new_or_existing  type      location    land_num  other  lat  lon  \
# ...

# %%
df_ownership_transfer[df_ownership_transfer["reason"]!="所有権移転売買"]
# Out:
#          register_num register_date register_type               reason pref  \
# 31189            9127    2023-02-16            単独  所有権移転売買/〔窓口/郵送〕/札なし  大阪府
# 31325           12610    2023-03-20            連続           所有権移転売買/郵送  大阪府
# 31457            1899    2023-01-27            単独         所有権移転売買/1963  京都府
# 31474           13061    2023-03-17            単独        所有権移転売買/34/送付  大阪府
# 31544           80552    2023-10-31            連続          所有権移転売買/103  大阪府
# ...               ...           ...           ...                  ...  ...
# 17195083        61507    2022-11-29            連続          所有権移転売買//送付  大阪府
# 17195253         2604    2022-01-20            連続         所有権移転売買/郵送希望  大阪府
# 17195418        44341    2022-08-26            連続          所有権移転売買//送付  大阪府
# 17196060         5733    2022-02-10            連先    所有権移転売買/郵送希望/郵送希望  大阪府
# 17196182        60842    2022-12-20            連続         所有権移転売買/郵送希望  大阪府
#
# ...

# %%
df_ownership_transfer
