# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
df_2014register = pd.read_csv("data/2014_受付帳.csv")
# Out:
# C:\Users\GUESTUSER\AppData\Local\Temp\ipykernel_8936\2779536150.py:1: DtypeWarning: Columns (9,10,18,23,24,27,36,37,38,39,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2014register = pd.read_csv("data/2014_受付帳.csv")

# %%
df_2014register.head()
# Out:
#   register_num register_date register_type               reason pref    city  \
# 0        13693    2014-04-25            連先              所有権移転売買  東京都     新宿区
# 1         3663    2014-07-04            連続  登記名義人の氏名等についての変更・更正  静岡県  賀茂郡河津町
# 2        14468    2014-11-25            連続             所有権移転・相続  静岡県     伊東市
# 3         1319    2014-02-04            単独             所有権移転・相続  静岡県     伊東市
# 4         2376    2014-03-03            単独             所有権移転・相続  静岡県     伊東市
#
#   new_or_existing  type   location chiban kaoku_number   land_num  other  lat  \
# 0               既  区分建物   新宿区新宿2丁目    NaN      90-1-37    90-1-37    NaN  NaN
# 1               既    建物   賀茂郡河津町逆川    NaN        852-1      852-1    NaN  NaN
# 2               既    建物       伊東市荻    NaN       536-74     536-74    NaN  NaN
# 3               既  区分建物      伊東市新井    NaN    484-30-12  484-30-12    NaN  NaN
# 4               既    建物  伊東市玖須美元和田    NaN      700-117    700-117    NaN  NaN
#
# ...

# %%
df_2014register['register_date'].str[:4].unique()
# Out:
# array(['2014'], dtype=object)

# %%
df_2014register.describe()
# Out:
#               other           lat           lon          size  \
# count  2.167125e+06  2.895792e+06  2.895792e+06  2.671534e+06
# mean   2.884368e+00  3.485361e+01  1.352467e+02  7.861239e+02
# std    2.187714e+01  5.217906e+00  1.844470e+01  1.420711e+04
# min    1.000000e+00 -1.000000e+00 -1.000000e+00  7.195000e-04
# 25%    1.000000e+00  3.487840e+01  1.377585e+02  7.978517e+01
# 50%    2.000000e+00  3.567178e+01  1.393614e+02  1.703478e+02
# 75%    3.000000e+00  3.596922e+01  1.397517e+02  3.477379e+02
# max    2.647900e+04  4.288997e+01  1.422214e+02  4.165015e+06
#
#        building_coverage_ratio  floor_area_ratio  official_price  \
# count             1.609974e+06      1.609974e+06    2.845472e+06
# mean              6.846511e+01      2.242596e+02    3.148786e+05
# std               2.918355e+02      3.152011e+02    1.265069e+06
# min               3.000000e+01      5.000000e+01    1.650000e+03
# 25%               5.000000e+01      1.500000e+02    2.410000e+04
# ...

# %%
df_2014register.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4876536 entries, 0 to 4876535
# Data columns (total 44 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   register_num             object
#  1   register_date            object
#  2   register_type            object
#  3   reason                   object
#  4   pref                     object
#  5   city                     object
#  6   new_or_existing          object
#  7   type                     object
#  8   location                 object
#  9   chiban                   object
#  10  kaoku_number             object
#  11  land_num                 object
#  12  other                    float64
#  13  lat                      float64
#  14  lon                      float64
#  15  size                     float64
#  16  building_coverage_ratio  float64
#  17  floor_area_ratio         float64
#  18  use_district             object
#  19  official_price           float64
# ...

# %%
len(df_2014register)
# Out:
# 4876536

# %%
len(df_2014register["register_num"].unique())
# Out:
# 119884
