# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
df_owner = pd.read_excel("C:/後藤研/修士研究/data/【サンプルデータ】所有者事項証明書_区分建物.xlsx")
# df = pd.read_excel("C:/Users/fwdkdsa/OneDrive/後藤研/修士/TRUSTART/【サンプルデータ】所有者事項証明書_区分建物.xlsx")

# %%
df_owner.head()
# Out:
#                                      id  no type        location land_number  \
# 0  d4d9d4a7-a9b3-4a9c-939c-7e3975fe8e4e   1   区建       岡山県倉敷市田ノ上   661-4-401
# 1  e634a0fd-8e7d-4c99-a643-32acac5ac671   2   区建    岡山県倉敷市老松町３丁目   376-1-102
# 2  cecfd301-ef22-469e-89c3-845d37af6c52   3   区建   岡山県岡山市北区大元１丁目   7-110-902
# 3  c2529bc3-c8f7-4ee1-b22c-09fc1e0d2b56   4   区建   岡山県岡山市北区大元１丁目   7-110-902
# 4  046766d1-69a2-450f-b46a-c185bb3c3757   5   区建  岡山県岡山市北区奉還町１丁目    1-13-903
#
#    branch_number                      owner_address owner_name  \
# 0              1        倉敷市田ノ上６６１番地４（アルファウィズ老松４０１号）       中原功次
# 1              1                倉敷市老松町三丁目１４番３３－１０２号       岡田里佳
# 2              1                  岡山市大元一丁目７番２２－９０２号       藤井実恵
# 3              2                   岡山市北区上中野一丁目４番１１号       藤井実恵
# 4              1  岡山市北区奉還町一丁目１１番８号ポレスターガーデンシティ清心９０３       羽原真美
#
#   ownership_share registration_application_date  free_input_field  \
# ...

# %%
df_owner_land = pd.read_csv("C:\後藤研\修士研究\data\所有者事項データ_土地.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Barre\AppData\Local\Temp\ipykernel_10384\113676811.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df_owner_land = pd.read_csv("C:\後藤研\修士研究\data\所有者事項データ_土地.csv")
# C:\Users\Barre\AppData\Local\Temp\ipykernel_10384\113676811.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_owner_land = pd.read_csv("C:\後藤研\修士研究\data\所有者事項データ_土地.csv")

# %%
df_owner_land.head()
# Out:
#    no type       location land_number  branch_number  \
# 0  17   土地  東京都世田谷区上野毛１丁目       255-1              4
# 1  29   土地  東京都世田谷区上野毛１丁目       255-1             16
# 2  36   土地  東京都世田谷区上野毛１丁目       255-1             23
# 3  42   土地  東京都世田谷区上野毛１丁目       255-1             29
# 4  45   土地  東京都世田谷区上野毛１丁目       255-1             32
#
#                    owner_address owner_name ownership_share  \
# 0        東京都世田谷区上野毛一丁目３１番１１－４０６号       加茂養子      １００００分の３５４
# 1           世田谷区上野毛一丁目３１番１１－５０４号      杉原眞理子      １００００分の１７３
# 2           世田谷区上野毛一丁目３１番１１－２０１号       丹野義夫      １００００分の３４７
# 3           世田谷区上野毛一丁目３１番１１－３０５号       白水朝日      １００００分の３３７
# 4  東京都稲城市矢野口１６８７番地ペアサイドマンション４０１号        野澤隆      １００００分の３４６
#
#   registration_application_date free_input_field      company_name  \
# 0                 2023年4月1日 土曜日              NaN  一般社団法人 全国住宅ローン救済
# 1                 2023年4月1日 土曜日              NaN  一般社団法人 全国住宅ローン救済
# 2                 2023年4月1日 土曜日              NaN  一般社団法人 全国住宅ローン救済
# ...
